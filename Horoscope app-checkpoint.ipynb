# %% [markdown]
# Flowchart
# 1. welcome to app with text and pic
# 2. login and details
# 3. details should have name birth date birth place birth time continue ask save aur discard
# 4. moon pic with options
# 5. options should be
#    1.know about your zodiac sign
#    2.todays horoscope
#    3.know about your future presumptions
#    4.birth chart calculator{name day date time birth place  etc given confirm then birth chart pic}
#    5.your profile
# 6. end

# %%
import simple_colors as color

# %%
print(color.blue("\t\t\t\t\tZodiacVibe",['underlined','bold','italic']))
print(color.blue("\t\t\t\tYour Zodiac Companion",['underlined','bold','italic']))
from IPython.display import Image, display
display(Image(url="ho-removebg-preview.png",width=200, height=200))
l=str(input("LoginId: "))
from getpass import getpass
pas= getpass("Enter Password: ")
print(color.yellow("Login Succesful!!!"))
print(color.green("Before We get started, We would like to know more about you!!"))
n= str(input("Your Name:"))
g= input("Gender: ")
b= input("Your birth date(dd/mm): ")
y= input("Your birth year: ")
p= input("Your birth place: ")

Ar = ['21/03','22/03','23/03','24/03','25/03','26/03','27/03','28/03','29/03','30/03','31/03','01/04','02/04','03/04','04/04','05/04','06/04','07/04','08/04','09/04','10/04','11/04','12/04','13/04','14/04','15/04','16/04','17/04','18/04','19/04']

Ta = ['20/04','21/04','22/04','23/04','24/04','25/04','26/04','27/04','28/04','29/04','30/04','01/05','02/05','03/05','04/05','05/05','06/05','07/05','08/05','09/05','10/05','11/05','12/05','13/05','14/05','15/05','16/05','17/05','18/05','19/05','20/05']

Ge = ['21/05','22/05','23/05','24/05','25/05','26/05','27/05','28/05','29/05','30/05','31/05','01/06','02/06','03/06','04/06','05/06','06/06','07/06','08/06','09/06','10/06','11/06','12/06','13/06','14/06','15/06','16/06','17/06','18/06','19/06','20/06','21/06']
     
Can= ['22/06','23/06','24/06','25/06','26/06','27/06','28/06','29/06','30/06','01/07','02/07','03/07','04/07','05/07','06/07','07/07','08/07','09/07','10/07','11/07','12/07','13/07','14/07','15/07','16/07','17/07','18/07','19/07','20/07','21/07','22/07']

Leo= ['23/07','24/07','25/07','26/07','27/07','28/07','29/07','30/07','31/07','01/08','02/08','03/08','04/08','05/08','06/08','07/08','08/08','09/08','10/08','11/08','12/08','13/08','14/08','15/08','16/08','17/08','18/08','19/08','20/08','21/08','22/08']

Vi = ['23/08','24/08','25/08','26/08','27/08','28/08','29/08','30/08','31/08','01/09','02/09','03/09','04/09','05/09','06/09','07/09','08/09','09/09','10/09','11/09','12/09','13/09','14/09','15/09','16/09','17/09','18/09','19/09','20/09','21/09','22/09']

Li = ['23/09','24/09','25/09','26/09','27/09','28/09','29/09','30/09','01/10','02/10','03/10','04/10','05/10','06/10','07/10','08/10','09/10','10/10','11/10','12/10','13/10','14/10','15/10','16/10','17/10','18/10','19/10','20/10','21/10','22/10','23/10']

Sc = ['24/10','25/10','26/10','27/10','28/10','29/10','30/10','31/10','01/11','02/11','03/11','04/11','05/11','06/11','07/11','08/11','09/11','10/11','11/11','12/11','13/11','14/11','15/11','16/11','17/11','18/11','19/11','20/11','21/11']

Sa = ['22/11','23/11','24/11','25/11','26/11','27/11','28/11','29/11','30/11','01/12','02/12','03/12','04/12','05/12','06/12','07/12','08/12','09/12','10/12','11/12','12/12','13/12','14/12','15/12','16/12','17/12','18/12','19/12','20/12']

Ca = ['22/12','23/12','24/12','25/12','26/12','27/12','28/12','29/12','30/12','31/12','01/01','02/01','03/01','04/01','05/01','06/01','07/01','08/01','09/01','10/01','11/01','12/01','13/01','14/01','15/01','16/01','17/01','18/01','19/01']

Aq = ['20/01','21/01','22/01','23/01','24/01','25/01','26/01','27/01','28/01','29/01','30/01','31/01','01/02','02/02','03/02','04/02','05/02','06/02','07/02','08/02','09/02','10/02','11/02','12/02','13/02','14/02','15/02','16/02','17/02','18/02']

Pi = ['19/02','20/02','21/02','22/02','23/02','24/02','25/02','26/02','27/02','28/02','29/02','01/03','02/03','03/03','04/03','05/03','06/03','07/03','08/03','09/03','10/03','11/03','12/03','13/03','14/03','15/03','16/03','17/03','18/03','19/03','20/03']

if b in Ar:
    print(color.magenta("Turns Out, You Are a Aries♈.",'bold'))
elif b in Ta:
    print(color.magenta("Turns Out, You Are a Taurus♉.",'bold'))
elif b in Ge:
    print(color.magenta("Turns Out, You Are a Gemini♊.",'bold'))
elif b in Can:
    print(color.magenta("Turns Out, You Are a Cancer♋.",'bold'))
elif b in Leo:
    print(color.magenta("Turns Out, You Are a Leo♌.",'bold'))
elif b in Vi:
    print(color.magenta("Turns Out, You Are a Virgo♍.",'bold'))
elif b in Li:
    print(color.magenta("Turns Out, You Are a Libra♎.",'bold'))
elif b in Sc:
    print(color.magenta("Turns Out, You Are a Scorpio♏.",'bold'))
elif b in Sa:
    print(color.magenta("Turns Out, You Are a Sagittarius♐.",'bold'))
elif b in Ca:
    print(color.magenta("Turns Out, You Are a Capricorn♑.",'bold'))
elif b in Aq:
    print(color.magenta("Turns Out, You Are a Aquarius♒.",'bold'))
elif b in Pi:
    print(color.magenta("Turns Out, You Are a Pisces♓.",'bold'))
else:
    print(color.magenta("Invalid Date!!"))
print(color.red('''
Choose from the option given below:
1. Today's horoscope
2. Know about your zodiac sign
3. Know about your Qualities and Future Presumptions
4. Birth Chart calculator
5. Your profile
6. Exit 
'''))
op= int(input("Your option here: "))
while op!=6:
    if op==1:
        print(color.red("Today's Horoscope...",['bold','underlined']))
        from IPython.display import Image, display
        display(Image(url="moons.jpeg",width=300, height=200))
        if b in Ar:
            print(color.cyan('''
            ARIES:-
            Your polite behaviour will be appreciated. Many people will shower verbal praise on you. 
            You will obtain benefits from commissions- dividends- or royalties. 
            Your partner would be supportive and helpful. Love journey sweet but 
            short lived Do not make any commitment unless you are sure of honoring it.
            Today, you should drive your vehicle carefully while coming back home from
            the office at night, otherwise an accident may occur and you may fall ill
            for several days. Your spouse might get too busy for you today.
            Lucky Number :- 1
            Lucky Color :- Orange and Gold
            Remedy :- Feed fish to make love life interesting.
            '''))
        elif b in Ta:
            print(color.cyan('''
            TAURUS:-
            You are likely to spend your time in sports to maintain your physical stamina. 
            Improvement in finances will make it convenient for you to purchase essential items.
            Your pleasant behaviour would enlighten the family life. Few people can resist an
            individual with such a sincere smile. When you can get well along with others-
            you are like a fragrant flower. Erratic behaviour of your darling ruin romance today.
            You are likely to gain- if you present your ideas well and show your determination
            and enthusiasm at work. Amidst your busy life, you will get enough time for yourself 
            today and be able to do your favorite things. Your spouse might act too self-centered today.
            Lucky Number :- 1
            Lucky Color :- Orange and Gold
            Remedy :- Using black coloured clothing often will ensure a stable and strong love life.
            '''))
        elif b in Ge:
            print(color.cyan('''
            GEMINI:-
            Your charming behaviour will attract attention. Financial hassles seem to get over 
            as your parents extend support. Your ability to impress others will bring rewards.
            Sex appeal give desired result Do not enter into any joint venture- as partners
            will try to take advantage of you. You will try to devote your time to your lover,
            but due to some important work, you will not be able to do the needful. 
            Your partner might do something fabulous unintentionally, which will be
            really unforgettable.
            Lucky Number :- 8
            Lucky Color :- Black and Blue
            Remedy :- Give respect and affection to mother, mother-like figures and elderly
            women for quick and constant growth in business/career.
            '''))
        elif b in Can:
            print(color.cyan('''
            CANCER:-
            Avoid overeating and keep a check on your weight. It's another high-energy day and unexpected 
            gains are foreseen. Unexpected gifts and presents from relatives 
            and friends. Today, you will realize how much your sweetheart loves you.
            Your business sense and your ability to negotiate will bring you gains.
            You would like to spend your time with people close to your heart,
            but won't be able to do so. You will have a stressful relationship with 
            your spouse and there might be serious discord that will last longer than
            it should.
            Lucky Number :- 2
            Lucky Color :- Silver and White
            Remedy :- Offer/flow raw turmeric in running water for great health.
           '''))
        elif b in Leo:
            print(color.cyan('''
            LEO:-
            Cold attitude of a friend may offend you. But try to keep your cool. 
            Let it not torment you rather strive to avoid misery. The court will make
            decisions in your favour today if you were involved in a case regarding
            money-related matters. It will benefit you financially. A good day to 
            revive old contacts and relations. Romance would be pleasurable and
            highly exciting. Do not come under pressure of others when making 
            important business decisions. The natives of this zodiac sign can 
            watch a movie or match at home with their siblings today. 
            By doing this, love will increase among you people.
            Your partner might do something fabulous unintentionally, 
            which will be really unforgettable.
            Lucky Number :- 9
            Lucky Color :- Red and Maroon
            Remedy :- Use Gangajal for auspicious health benefits.
            '''))
        elif b in Vi:
            print(color.cyan('''
            VIRGO:-
            Your hope will bloom like a rich delicate fragrant and dazzling flower. 
            Today, businessmen of this zodiac sign should stay away from the members
            of their household who ask for your financial help and do not return it
            later. Good time to get involved into activities that include youngsters.
            Avoid raising controversial issues, if you happen to go on a date today.
            Professional advancements for some. Be original in your conversation as
            putting up an act would get you no where. Wrong communication might create
            a trouble today, but you will be able to manage it by sitting and talking.
            Lucky Number :- 8
            Lucky Color :- Black and Blue
            Remedy :- For increasing deep bonding with your lover, worship Goddess Saraswati.
            '''))
        elif b in Li:
            print(color.cyan('''
            LIBRA:-
            Unnecessary tension and worry could sap the juice of your life and leave you dry.
            Better to get rid of these otherwise they would only aggravate your problem.
            Today, your parents may become worried because of your extravagant lifestyle
            and spending, and therefore you may have to fall prey to their anger. Evening 
            with friends will be good for pleasure as well as some holiday planning. 
            Chances of someone proposing on the cards. Support and appreciation from
            seniors will raise your morale and confidence. You know the importance
            of personal space, and you are likely to get a lot of free time today.
            In this time, you can play a game or go to the gym. With just little
            efforts, the day might become the best day of your married life.
            Lucky Number :- 1
            Lucky Color :- Orange and Gold
            Remedy :- Engrave Mangal (Mars) Yantra in a gold ring and wear it to attain good health.
            '''))
        elif b in Sc:
            print(color.cyan('''
            SCORPIO:-
            Friends supportive and will keep you happy. Any issues related to money can get solved
            today and you can attain financial benefits. You can expect problems at home- if you do not
            spend time with family members. Lovers will excessively be considerate of family feelings.
            Support from seniors as well as colleagues at workplace lifts your morale. You have to learn 
            to give time to relationships and people in your life you value the most. Today, you will realize
            that your marriage had never been so beautiful.
            Lucky Number :- 3
            Lucky Color :- Saffron and Yellow
            Remedy :- Flowing empty mud pot in flowing water along with lid will increase career prospects.
            '''))
        elif b in Sa:
            print(color.cyan('''
            SAGITTARIUS:-
            Blessings of a saintly person will give peace of mind. Today, you can come across a person
            in a party who can give you some important advice to strengthen your economic side. 
            An old contact might create some problems for you You will tease your romantic partner 
            by prolonging your call. Don't promise anything till you are sure you can deliver it. 
            It is good to spend time alone, but you can grow anxious over something going on in your mind. 
            Therefore, we advise you to contact an experienced person and share your troubles with them.
            Difference of views might create an argument between you and your partner today.
            Lucky Number :- 9
            Lucky Color :- Red and Maroon
            Remedy :- By touching the feet and obtaining the blessings of elderly women continuously for 108 days,
            you lead a happy and contented family life.
            '''))
        elif b in Ca:
            print(color.cyan('''
            CAPRICORN:-
            Your tremendous effort and timely support by family members would bring desired results.
            But keep working hard to maintain current spirit going. You know the importance of money 
            very well, which is why the money you save today will be useful in the future and
            get out of any major difficulty. Youngsters may seek some advice on school projects.
            Day is filled with joy and happiness with a lovely message. Today your artistic and 
            creative ability will attract lot of appreciation and bring you unexpected rewards.
            Those who were very busy for the last few days will finally get to enjoy their own time.
            Today, you will realize that all the vows taken on your marriage were true.
            Your spouse is your soulmate.
            Lucky Number :- 9
            Lucky Color :- Red and Maroon
            Remedy :- Feed cows and brown dogs for blissful family life.
            '''))
        elif b in Aq:
            print(color.cyan('''
            AQUARIUS:-
            You are unable to make any progress because of your pessimistic attitude. 
            It is high time for you to realise that worry has retarded your thinking power.
            Look at the brighter side and you will see a definite change in your discretion.
            People who had bought land and now want to sell it can come across a good buyer today
            and acquire a good amount for it. You need to relax and try to find happiness amongst
            close friends and family members Try to control your speech as your harsh words can mar
            the peace and perturb the smooth pace of the ties with your sweetheart. 
            Don't mix business with pleasure. Today, you'll understand the importance of relationships
            as you'll spend the majority of your time with your family members. Your life-partner might
            give less care and importance to your family members as compared to his/her family members in
            times of need today.
            Lucky Number :- 7
            Lucky Color :- Cream and White
            Remedy :- Eat food in a bronze plate, and bring in auspiciousness to your love life. '''))
        elif b in Pi:
            print(color.cyan('''
            PISCES:-
            Be careful not to neglect yourself when it comes to health matters.
            Today, you need to stay away from such friends who ask you to loan money and then do not return it.
            Friends will offer you good advice regarding your personal life. Today, you will plan an outing
            with your lover, but due to some important work showing up, you won't be able to go. This can lead 
            to a heated argument between you and your beloved. If you were trying to talk to someone at work 
            since long, you might get lucky today. You will make commitment to the people who look up to you for help.
            Today, your life partner will show you all the good feeling he/she has for you inspite of all odds
            happened in the recent past.
            Lucky Number :- 4
            Lucky Color :- Brown and Grey
            Remedy :- Wear a Copper bangle for continued good health.'''))
        else:
            print(color.cyan("Invalid Date Means No Zodiac Sign..Sorry!!😔"))
    if op==2:
        print(color.red("Know about your zodiac sign...",['bold','underlined']))
        if b in Ar:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Aries.png",width=100, height=100))
            print(color.cyan('''
            ARIES:-
            Element: Fire
            Ruling Planet: Mars
            Personality Traits: Aries individuals are often described as energetic, enthusiastic, and passionate.
            They tend to be natural leaders with a strong desire to take charge and initiate action.
            They are known for their competitive spirit, assertiveness, and courage.
            Strengths: Aries are known for their determination, creativity, and willingness to take risks. 
            They are often innovative and enjoy challenges.
            Challenges: Aries individuals might sometimes be seen as impatient, impulsive, and quick-tempered.
            They might rush into things without thinking them through.
            Interests: Aries tend to be attracted to activities that allow them to express themselves, compete, and lead.
            They might enjoy sports, entrepreneurship, and creative pursuits.
            Compatibility: Aries is generally compatible with other fire signs (Leo and Sagittarius) and
            also with air signs (Gemini, Libra, and Aquarius).
            Career: Aries individuals often thrive in careers that allow them to be at the forefront, 
            make decisions, and take on challenges. 
            They might excel in roles that require leadership, creativity, and problem-solving.
            '''))
        elif b in Ta:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Taurus.png",width=100, height=100))
            print(color.cyan('''
            TAURUS:-
            Element: Earth
            Ruling Planet: Venus
            Personality Traits: Taurus individuals are often characterized as reliable, patient, and practical. 
            They are known for their strong willpower, determination, and stability.
            Strengths: Taurus individuals have a strong sense of loyalty and are dependable friends and partners.
            They are hardworking and often value material comforts and security.
            Challenges: Taurus individuals can sometimes be seen as stubborn or resistant to change. 
            They might also have a tendency to hold onto grudges.
            Interests: Taurus individuals often enjoy the finer things in life, such as good food, art, music, and comfort.
            They might also have a green thumb and enjoy gardening.
            Compatibility: Taurus is generally compatible with other earth signs (Virgo and Capricorn) 
            and also with water signs (Cancer, Scorpio, and Pisces).
            Career: Taurus individuals excel in careers that allow them to use their practical and patient nature.
            They might thrive in fields such as finance, real estate, and the arts.
            '''))
        elif b in Ge:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Gemini.png",width=100, height=100))
            print(color.cyan('''
            GEMINI:-
            Element: Air
            Ruling Planet: Mercury
            Personality Traits: Gemini individuals are often described as curious, adaptable, and communicative.
            They are known for their quick wit, versatility, and love for learning and socializing.
            Strengths: Geminis have excellent communication skills and are often adept at expressing themselves verbally.
            They are intellectually curious and enjoy exploring various subjects.
            Challenges: Geminis might sometimes be seen as indecisive due to their ability to see multiple sides of a situation.
            They could also be prone to restlessness and inconsistency.
            Interests: Geminis often have a wide range of interests and hobbies. 
            They enjoy engaging in conversations, reading, writing, and exploring different cultures.
            Compatibility: Gemini is generally compatible with other air signs (Libra and Aquarius) and
            also with fire signs (Aries, Leo, and Sagittarius).
            Career: Gemini individuals thrive in careers that allow them to communicate, gather information, 
            and adapt to changing situations.
            They might excel in fields like journalism, sales, and communication-related roles.
            '''))
        elif b in Can:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Cancer.png",width=100, height=100))
            print(color.cyan('''
            CANCER:-
            Element: Water
            Ruling Planet: Moon
            Personality Traits: Cancer individuals are often described as nurturing, intuitive, and sensitive.
            They are known for their emotional depth, empathy, and strong connection to family and home.
            Strengths: Cancers are deeply compassionate and caring. They have a strong sense of intuition and 
            can understand the emotions of others. They are also loyal and protective of their loved ones.
            Challenges: Cancers might sometimes struggle with mood swings and can be prone to dwelling on past
            experiences or perceived slights.
            Interests: Cancers often enjoy activities related to home, family, and creativity. They have a 
            natural affinity for arts and crafts, cooking, and creating a comfortable living space.
            Compatibility: Cancer is generally compatible with other water signs (Scorpio and Pisces) and also 
            with earth signs (Taurus, Virgo, and Capricorn).
            Career: Cancer individuals excel in careers that allow them to use their nurturing qualities and 
            emotional intelligence. They might thrive in fields like healthcare, counseling, and professions 
            related to art and design.
            '''))
        elif b in Leo:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Leo.png",width=100, height=100))
            print(color.cyan('''
            LEO;-
            Element: Fire
            Ruling Planet: Sun
            Personality Traits: Leo individuals are often described as confident, charismatic, and enthusiastic.
            They are known for their leadership qualities, creativity, and desire for recognition.
            Strengths: Leos have a natural magnetism and are often the center of attention in social settings. 
            They are confident, self-assured, and have a strong sense of self-worth.
            Challenges: Leos might sometimes come across as overly proud or domineering. They can also be sensitive
            to criticism and seek validation from others.
            Interests: Leos enjoy activities that allow them to express themselves creatively. 
            They might be drawn to performing arts, fashion, and any endeavor where they can shine.
            Compatibility: Leo is generally compatible with other fire signs (Aries and Sagittarius) and also with 
            air signs (Gemini, Libra, and Aquarius).
            Career: Leo individuals excel in careers that allow them to be in the spotlight and utilize their 
            leadership skills. They might thrive in fields like entertainment, entrepreneurship, and leadership roles.
            '''))
        elif b in Vi:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Virgo.png",width=100, height=100))
            print(color.cyan('''
            VIRGO:-
            Element: Earth
            Ruling Planet: Mercury
            Personality Traits: Virgo individuals are often described as practical, detail-oriented, and analytical.
            They are known for their precision, organization, and strong work ethic.
            Strengths: Virgos have a keen eye for detail and are excellent at organizing and planning.
            They are reliable, diligent, and often serve as valuable problem solvers.
            Challenges: Virgos might sometimes be seen as perfectionists, setting high standards for themselves and others.
            They could also overthink and worry about minor details.
            Interests: Virgos often enjoy activities that engage their intellect and allow them to be of service. 
            They might have an affinity for hobbies like writing, research, and health-related pursuits.
            Compatibility: Virgo is generally compatible with other earth signs (Taurus and Capricorn) and also with
            water signs (Cancer, Scorpio, and Pisces).
            Career: Virgo individuals excel in careers that require attention to detail, analysis, and problem-solving. 
            They might thrive in fields such as healthcare, research, and administrative roles.'''))
        elif b in Li:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Libra.png",width=100, height=100))
            print(color.cyan('''
            LIBRA:-
            Element: Air
            Ruling Planet: Venus
            Personality Traits: Libra individuals are often described as diplomatic, charming, and social. 
            They are known for their sense of fairness, balance, and strong desire for harmonious relationships.
            Strengths: Libras have a natural ability to see both sides of an issue and find compromise. 
            They excel at mediating conflicts and promoting cooperation.
            Challenges: Libras might sometimes have difficulty making decisions due to their desire to please others.
            They could also avoid confrontation at the expense of their own needs.
            Interests: Libras often enjoy activities that involve art, culture, and socializing. 
            They have an appreciation for beauty, and they might be drawn to fashion, music, and the arts.
            Compatibility: Libra is generally compatible with other air signs (Gemini and Aquarius) 
            and also with fire signs (Aries, Leo, and Sagittarius).
            Career: Libra individuals excel in careers that involve communication, negotiation, and creativity. 
            They might thrive in fields such as law, diplomacy, and design.'''))
        elif b in Sc:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Scorpio.png",width=100, height=100))
            print(color.cyan('''
            SCORPIO:-
            Element: Water
            Ruling Planets: Mars (traditional ruler) and Pluto (modern ruler)
            Personality Traits: Scorpio individuals are often described as intense, passionate, and resourceful.
            They are known for their deep emotions, determination, and strong sense of purpose.
            Strengths: Scorpios have a natural magnetism and the ability to delve into complex subjects.
            They are skilled at uncovering hidden truths and are excellent problem solvers.
            Challenges: Scorpios might sometimes struggle with possessiveness and jealousy. 
            Their intensity can sometimes lead to conflicts or power struggles.
            Interests: Scorpios often enjoy activities that allow them to explore the mysteries of life, 
            such as psychology, astrology, and the occult. They might also have a love for art and music.
            Compatibility: Scorpio is generally compatible with other water signs (Cancer and Pisces) 
            and also with earth signs (Taurus, Virgo, and Capricorn).
            Career: Scorpio individuals excel in careers that require depth of thought, investigation, and dedication.
            They might thrive in fields like research, psychology, and roles involving analysis.'''))
        elif b in Sa:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Sagittarius.png",width=100, height=100))
            print(color.cyan('''
            SAGITTARIUS:-
            Element: Fire
            Ruling Planet: Jupiter
            Personality Traits: Sagittarius individuals are often described as adventurous, optimistic, and open-minded.
            They are known for their love of exploration, philosophical thinking, and desire for freedom.
            Strengths: Sagittarians have an infectious enthusiasm and a positive outlook on life. 
            They are often honest and straightforward, valuing truth and authenticity.
            Challenges: Sagittarians might sometimes come across as tactless due to their direct nature.
            They could also struggle with commitment or focusing on details.
            Interests: Sagittarius individuals enjoy activities that involve travel, learning, and expanding their horizons. 
            They might be drawn to higher education, philosophy, and outdoor pursuits.
            Compatibility: Sagittarius is generally compatible with other fire signs (Aries and Leo)
            and also with air signs (Gemini, Libra, and Aquarius).
            Career: Sagittarius individuals excel in careers that allow them to be dynamic, explore new territories, 
            and share their knowledge. They might thrive in fields like travel, education, and media.'''))
        elif b in Ca:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Capricorn.png",width=100, height=100))
            print(color.cyan('''
            CAPRICORN:-
            Element: Earth
            Ruling Planet: Saturn
            Personality Traits: Capricorn individuals are often described as responsible, disciplined, and ambitious. 
            They are known for their strong work ethic, practicality, and determination.
            Strengths: Capricorns are reliable and dependable, often taking on leadership roles due to their 
            responsible nature. They are excellent at setting and achieving long-term goals.
            Challenges: Capricorns might sometimes be seen as too focused on work or overly serious. 
            They could also struggle with delegating tasks and seeking relaxation.
            Interests: Capricorn individuals enjoy activities that allow them to demonstrate their skills and
            achieve tangible results. They might have an interest in business, finance, and building things.
            Compatibility: Capricorn is generally compatible with other earth signs (Taurus and Virgo)
            and also with water signs (Cancer, Scorpio, and Pisces).
            Career: Capricorn individuals excel in careers that require structure, organization, and attention to detail.
            They might thrive in fields such as business, law, and management roles.'''))
        elif b in Aq:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Aquarius.png",width=100, height=100))
            print(color.cyan('''
            AQUARIUS:-
            Element: Air
            Ruling Planets: Saturn (traditional ruler) and Uranus (modern ruler)
            Personality Traits: Aquarius individuals are often described as innovative, independent, and humanitarian.
            They are known for their unique perspectives, intellectual curiosity, and desire for social change.
            Strengths: Aquarians have a strong sense of individuality and often possess visionary ideas.
            They are open-minded, progressive, and value the well-being of the community.
            Challenges: Aquarians might sometimes be perceived as detached or aloof due to their focus on ideas over 
            emotions. They could also be resistant to traditional norms.
            Interests: Aquarius individuals enjoy activities that engage their intellect and creativity. 
            They might be drawn to technology, science, social activism, and humanitarian causes.
            Compatibility: Aquarius is generally compatible with other air signs (Gemini and Libra)
            and also with fire signs (Aries, Leo, and Sagittarius).
            Career: Aquarius individuals excel in careers that involve innovation, social causes, and problem-solving.
            They might thrive in fields like technology, research, and social justice. '''))
        elif b in Pi:
            from IPython.display import Image, display
            display(Image(url="https://www.astrosage.com/images/sign/Pisces.png",width=100, height=100))
            print(color.cyan('''
            PISCES:-
            Element: Water
            Ruling Planets: Jupiter (traditional ruler) and Neptune (modern ruler)
            Personality Traits: Pisces individuals are often described as compassionate, intuitive, and artistic. 
            They are known for their sensitivity, empathy, and deep emotional connections.
            Strengths: Pisceans have a strong intuition and an ability to understand the emotions of others.
            They are creative, imaginative, and often possess a dreamy nature.
            Challenges: Pisceans might sometimes be perceived as indecisive or prone to escapism as a way
            to cope with life's challenges. They could also struggle with setting boundaries.
            Interests: Pisces individuals enjoy activities that allow them to express their emotions and creativity.
            They might be drawn to art, music, writing, and spirituality.
            Compatibility: Pisces is generally compatible with other water signs (Cancer and Scorpio) 
            and also with earth signs (Taurus, Virgo, and Capricorn).
            Career: Pisces individuals excel in careers that involve creativity, empathy, and helping others.
            They might thrive in fields like art, healthcare, counseling, and humanitarian work.
            '''))
        else:
            print(color.cyan("Invalid Date Means No Zodiac Sign..Sorry!!😔"))
    if op==3:
        print(color.red("Know about your Qualities and Future Presumptions...",['bold','underlined']))
        if b in Ar:
            print(color.cyan('''
            ARIES:-
            Positive Traits:
            Courageous: Aries individuals are known for their bravery and fearlessness. They often have the courage to face challenges head-on.
            Energetic: Aries is a high-energy sign, and its individuals tend to be dynamic and enthusiastic. They approach life with vigor and vitality.
            Optimistic: Aries individuals generally have an optimistic outlook on life. They believe in their ability to overcome obstacles and achieve their goals.
            Initiators: As natural leaders, Aries individuals are skilled at taking the first step. They are good at starting projects and motivating others to join in.
            Independent: Aries value their independence and prefer to make their own decisions. They are self-reliant and don't mind taking the road less traveled.
            Charismatic: Their magnetic and confident nature often makes Aries individuals charismatic and appealing to others.
            
            Challenging Traits:
            Impulsiveness: Aries individuals might act on their impulses without considering the consequences. This can sometimes lead to hasty decisions.
            Impatience: They often prefer quick results and can become frustrated if things don't progress as fast as they'd like.
            Competitiveness: While healthy competition can be motivating, Aries individuals might become overly competitive, which can strain relationships.
            Short-Temper: Due to their fiery nature, Aries individuals might have a short fuse when it comes to frustrations and disagreements.
            Restlessness: Aries can get bored easily and seek constant excitement. This might lead to restlessness and difficulty sticking to long-term commitments.
            Relationships:
            In relationships, Aries individuals are passionate and can be extremely devoted. However, they value their independence and need a partner who respects their need for personal space. They are loyal and protective of those they care about.

            Career:
            Aries individuals often excel in careers that require leadership, innovation, and creativity. They might thrive as entrepreneurs, athletes, managers, and in roles where they can take charge and make decisions.

            Health:
            Aries individuals should be mindful of stress due to their energetic nature. Engaging in regular physical activities and finding healthy outlets for their energy is important for their well-being.

            Remember that astrology is based on belief systems and interpretations, and not everyone subscribes to its teachings. The personality traits associated with each zodiac sign are generalizations and might not accurately represent every individual.
            '''))
        elif b in Ta:
            print(color.cyan('''
            TAURUS:-
            Additional Traits and Information:

            Stability: Taurus individuals value stability and often work diligently to create a secure and comfortable environment for themselves and their loved ones.
            Sensual: Ruled by Venus, the planet of love and beauty, Taurus individuals are known for their appreciation of sensory pleasures. They often have a heightened sense of taste, touch, and aesthetics.
            Materialism: While they value security and comfort, Taurus individuals should be cautious not to become overly materialistic or possessive.
            Practicality: Taurus individuals have a grounded and pragmatic approach to life. They tend to make decisions based on practicality rather than impulsive choices.
            Creativity: Many Taurus individuals possess a strong artistic side, whether it's expressed through visual arts, music, or other creative pursuits.
            As always, remember that astrology is based on beliefs and interpretations, and the traits associated with each zodiac sign are generalized. Individuals are unique, and their personalities are influenced by a wide range of factors beyond their zodiac sign.
            '''))
        elif b in Ge:
            
            print(color.cyan('''
            GEMINI:-
            Additional Traits and Information:

            Dual Nature: Geminis are symbolized by the Twins, which reflects their dual nature. They often have multifaceted personalities and can switch between different modes of thinking.
            Social: Gemini individuals are often the life of the party and enjoy being around people. They are skilled at networking and can easily strike up conversations.
            Restlessness: Due to their need for mental stimulation, Geminis might experience restlessness if they're not intellectually engaged.
            Playfulness: Geminis have a playful and youthful energy. They have a knack for finding humor in various situations and can lighten the mood in social settings.
            Curiosity: Geminis are naturally curious and are always seeking to expand their knowledge and experience new things.
            As with any zodiac sign, remember that individual personalities are shaped by a combination of factors, including upbringing, experiences, and personal choices. While astrology can provide insights, it's not a definitive guide to a person's character.
            '''))
        elif b in Can:
            
            print(color.cyan('''
            CANCER:-
            Additional Traits and Information:

            Emotional Depth: Cancers experience emotions deeply and can be quite sensitive. They often rely on their intuition to navigate social situations.
            Home-Centric: The home environment is especially important to Cancers. They often seek comfort and security within their personal space.
            Protective: Cancers are protective of their loved ones and can be fiercely loyal. They prioritize the well-being of those close to them.
            Cautious: Cancers tend to be cautious in their approach to new situations. They prefer to assess and understand the situation thoroughly before making decisions.
            Imagination: Many Cancers possess a vivid imagination and might have a creative outlet to express their feelings and ideas.
            It's important to remember that astrology offers general insights and tendencies associated with each zodiac sign. People are unique individuals shaped by a combination of factors beyond their zodiac sign.
            '''))
        elif b in Leo:
            
            print(color.cyan('''
            LEO:-
            Additional Traits and Information:

            Generosity: Leos are known for their generous nature and willingness to help others. They enjoy showering their loved ones with attention and gifts.
            Dramatic: Leos often have a flair for the dramatic and enjoy being part of exciting and expressive activities.
            Confidence: Leos exude confidence and often have a strong presence wherever they go. They have a natural ability to inspire and motivate others.
            Loyalty: Loyalty is important to Leos. They form deep connections with those they care about and are dedicated to their friendships and relationships.
            Optimism: Leos typically have an optimistic outlook on life and approach challenges with a positive attitude.
            As always, remember that while astrology can provide insights, individual personalities are shaped by a combination of factors. The traits associated with each zodiac sign are generalized and might not represent every individual.
            '''))
        elif b in Vi:
            
            print(color.cyan('''
            VIRGO:-
            Additional Traits and Information:

            Practicality: Virgos have a practical and realistic approach to life. They prefer tangible results and solutions that are based on practicality.
            Helpful: Virgos often find fulfillment in helping others. They have a strong sense of duty and enjoy being of service to their friends, family, and community.
            Modesty: Virgos tend to be humble and don't seek attention or recognition for their efforts. They quietly go about their work, often behind the scenes.
            Analytical: Virgos have an analytical mindset and enjoy solving puzzles and unraveling complexities. They often approach challenges with a logical perspective.
            Health Conscious: Many Virgos are health-conscious and pay attention to their well-being. They might focus on fitness, nutrition, and overall self-care.
            Remember that astrology provides a general framework for understanding personality traits, but individual personalities are shaped by various factors. The information provided here is a broad overview and might not apply to every Virgo individual.'''))
        elif b in Li:
            
            print(color.cyan('''
            LIBRA:-
            Additional Traits and Information:

            Harmony: Libras seek harmony and balance in all aspects of their lives. They have a strong aversion to conflict and work towards creating a peaceful environment.
            Social: Libras are social butterflies and enjoy being around people. They have a friendly and approachable demeanor that attracts others to them.
            Aesthetic: Ruled by Venus, the planet of beauty, Libras often have a refined taste and an eye for aesthetics. They value beauty in art, relationships, and their surroundings.
            Indecisiveness: Due to their desire for balance and fairness, Libras can sometimes struggle with decision-making, especially when faced with choices that might upset others.
            Empathy: Libras are empathetic and often put themselves in others' shoes to understand their perspectives.
            As always, remember that astrology provides a general overview of personality traits associated with each zodiac sign, but individual personalities are influenced by a multitude of factors. The information provided here is meant to be a starting point for understanding Libra's characteristics.'''))
        elif b in Sc:
            
            print(color.cyan('''
            SCORPIO:-
            Additional Traits and Information:

            Intensity: Scorpios are known for their intense emotions and unwavering determination. They approach life with a sense of purpose and commitment.
            Mystery: Scorpios have a mysterious aura that draws others in. They often prefer to keep some aspects of themselves private and hidden.
            Transformative: Scorpios are associated with transformation and regeneration. They have a natural ability to overcome challenges and rise from difficult situations.
            Loyalty: Scorpios are fiercely loyal to those they care about. They value deep, meaningful connections and often form strong bonds with friends and partners.
            Empowerment: Many Scorpios are driven by a desire for personal growth and empowerment. They are not afraid to confront their own shadows and evolve as individuals.
            As always, keep in mind that while astrology offers insights into personality traits, individuals are complex and influenced by a variety of factors. The information provided here is a general overview and might not capture every aspect of a Scorpio individual's personality.'''))
        elif b in Sa:
            
            print(color.cyan('''
            SAGITTARIUS:-
            Additional Traits and Information:

            Adventurous: Sagittarians have a natural sense of adventure and a love for exploring both physical and intellectual landscapes.
            Optimism: Sagittarians are eternal optimists, often seeing the silver lining even in challenging situations.
            Philosophical: Many Sagittarians have a philosophical and open-minded approach to life. They enjoy pondering the deeper meanings and seeking truth.
            Restlessness: Due to their love for change and exploration, Sagittarians might experience restlessness if they're confined to routine or restrictions.
            Independence: Freedom is highly important to Sagittarius individuals. They value their independence and need space to pursue their interests.
            As always, while astrology provides insights into personality traits, individual characteristics can vary widely. The information provided here is meant to offer a general overview of Sagittarius traits, but individuals are influenced by a combination of factors beyond their zodiac sign.'''))
        elif b in Ca:
            
            print(color.cyan('''
            CAPRICORN:-
            Additional Traits and Information:

            Ambition: Capricorns have a strong drive to succeed and often set high standards for themselves. They are willing to put in the effort required to achieve their goals.
            Practicality: Capricorns have a pragmatic approach to life and prefer to base their decisions on logic and practicality.
            Self-Discipline: Self-discipline is a hallmark of Capricorn individuals. They are able to overcome challenges through persistence and hard work.
            Reserved: Capricorns tend to be reserved in their emotions, often focusing more on actions than on expressing their feelings openly.
            Long-Term Vision: Capricorns have a knack for seeing the bigger picture and planning for the long term. They are skilled at creating strategies and achieving results over time.
            Remember that while astrology can provide insights, individual personalities are influenced by a variety of factors. The information provided here is a general overview and might not capture every aspect of a Capricorn individual's personality.'''))
        elif b in Aq:
            
            print(color.cyan('''
            AQUARIUS:-
            Additional Traits and Information:

            Humanitarian: Aquarians are often concerned with the greater good and social progress. They have a deep desire to contribute to positive change in society.
            Intellectual: Many Aquarians are highly intellectual and enjoy engaging in stimulating conversations and debates.
            Independence: Independence is crucial to Aquarius individuals. They value their freedom and might resist anything that feels restrictive.
            Unconventional: Aquarians often march to the beat of their own drum, embracing unconventional ideas and lifestyles.
            Friendship: Aquarians are known for their friendly and approachable demeanor. They form strong connections with friends who share their ideals.
            As always, keep in mind that while astrology offers insights into personality traits, individual characteristics can vary widely. The information provided here is meant to offer a general overview of Aquarius traits, but individuals are influenced by a combination of factors beyond their zodiac sign. '''))
        elif b in Pi:
            
            print(color.cyan('''
            PISCES:-
            Additional Traits and Information:

            Empathy: Pisces individuals have a strong sense of empathy and are often attuned to the emotions of those around them.
            Dreaminess: Many Pisces individuals have a dreamy and imaginative nature. They can sometimes be lost in their own thoughts and daydreams.
            Spirituality: Pisces is often associated with spiritual pursuits and a connection to the mystical. They might have a deep interest in exploring their inner worlds.
            Adaptability: Pisceans are adaptable and can navigate various situations with ease. They are often able to see the bigger picture.
            Compassion: Compassion and kindness are central to Pisces' nature. They are often driven by a desire to alleviate suffering in the world.
            As always, keep in mind that astrology provides insights into personality traits, but individual characteristics are influenced by a multitude of factors. The information provided here is meant to offer a general overview of Pisces traits, but individuals are unique and multifaceted.
            '''))
        else:
            print(color.cyan("Invalid Date Means No Zodiac Sign..Sorry!!😔"))
    if op==4:
        print(color.red("Birth Chart Calculator...",['bold','underlined']))
        print("We would like to know more about you to make your birth chart..")
        t= input("Your Birth Time(hh:mm:ss): ")
        print(color.magenta(f'''
        Your Name: {n}
        Your Gender: {g}
        Your DOB: {b}/{y}
        Your Birth Place: {p}
        Your Birth Time: {t}
        '''))
        e=str(input("Do you want to edit the already provided information(y/n): "))
        while e=='y':
            n= str(input("Your Name:"))
            g= input("Gender: ")
            b= input("Your birth date(dd/mm): ")
            y= input("Your birth year: ")
            p= input("Your birth place: ")
            t= input("Your Birth Time(hh:mm:ss): ")
            ee=str(input("Do you want to save changes(y/n): "))
            if ee=='y':
                print(color.magenta(f'''
                Your Name: {n}
                Your Gender: {g}
                Your DOB: {b}/{y}
                Your Birth Place: {p}
                Your Birth Time: {t}
                '''))
                break
            elif ee=='n':
                
                e=str(input("Do you want to edit the already provided information(y/n): "))
            else:
                print(color.magenta("Invalid Option"))
        print(color.green("Your Birth Chart is ready..😊"))
        if g=='Female' or g=='female' or g=='f' or g=='F':
            from IPython.display import Image, display
            display(Image(url="chart.png",width=300, height=300))
        elif g=='Male' or g=='male' or g=='m' or g=='M':
            from IPython.display import Image, display
            display(Image(url="chart1.png",width=300, height=300))
        else:
            print("Sorry!!Try again later!!!")
            
    if op==5:
        print(color.red("Your Profile...",['bold','underlined']))
        print(color.magenta(f'''
                Your Name: {n}
                Your Gender: {g}
                Your DOB: {b}/{y}
                Your Birth Place: {p}
                
                '''))
        
        
            
            
            
            
            
            
    
    
    print(color.red('''
    Choose from the option given below:
    1. Today's horoscope
    2. Know about your zodiac sign
    3. Know about your Qualities and Future Presumptions
    4. Birth Chart calculator
    5. Your profile
    6. Exit 
    '''))
    
    op= int(input("Your option here: ")) 
print(color.green("Bye Bye!!!",'bold'))
# Out:
# 					ZodiacVibe
# 				Your Zodiac Companion
# <img src="ho-removebg-preview.png" width="200" height="200"/>
# LoginId: Simran
# Enter Password: ········
# Login Succesful!!!
# Before We get started, We would like to know more about you!!
# Your Name:Simran Jethwani
# Gender: Female
# Your birth date(dd/mm): 04/03
# Your birth year: 2003
# Your birth place: Jaipur
# Turns Out, You Are a Pisces♓.
#
# Choose from the option given below:
# 1. Today's horoscope
# 2. Know about your zodiac sign
# 3. Know about your Qualities and Future Presumptions
# 4. Birth Chart calculator
# 5. Your profile
# 6. Exit
#
# Your option here: 4
# Birth Chart Calculator...
# We would like to know more about you to make your birth chart..
# Your Birth Time(hh:mm:ss): 23:06
#
#         Your Name: Simran Jethwani
#         Your Gender: Female
#         Your DOB: 04/03/2003
#         Your Birth Place: Jaipur
#         Your Birth Time: 23:06
#
# Do you want to edit the already provided information(y/n): y
# ...
